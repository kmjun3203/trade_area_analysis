# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("./서울시 상권분석서비스(영역-상권).csv", encoding='cp949')
df1
# Out:
#      상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  엑스좌표_값  와이좌표_값  \
# 0           A       골목상권  3110008         배화여자대학교(박노수미술관)  197093  453418
# 1           A       골목상권  3110009                   자하문터널  196991  455057
# 2           A       골목상권  3110010                   평창동서측  197064  456643
# 3           A       골목상권  3110017                   정독도서관  198581  453781
# 4           A       골목상권  3110018                  중앙고등학교  198883  453690
# ...       ...        ...      ...                     ...     ...     ...
# 1645        U       관광특구  3001492  명동 남대문 북창동 다동 무교동 관광특구  198397  451614
# 1646        U       관광특구  3001493            동대문패션타운 관광특구  200996  451976
# 1647        U       관광특구  3001494              종로?청계 관광특구  199796  452274
# 1648        U       관광특구  3001495                 잠실 관광특구  210188  446334
# 1649        U       관광특구  3001496             강남 마이스 관광특구  205282  445736
#
#       자치구_코드 자치구_코드_명    행정동_코드     행정동_코드_명    영역_면적
# ...

# %%
df2 = pd.read_csv("./서울시 상권분석서비스(점포-상권).csv", encoding="cp949")
df2
# Out:
#         기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                       상권_코드_명  \
# 0           20252        R       전통시장  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)
# 1           20252        R       전통시장  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)
# 2           20252        R       전통시장  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)
# 3           20252        R       전통시장  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)
# 4           20252        R       전통시장  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)
# ...           ...      ...        ...      ...                           ...
# 459505      20241        U       관광특구  3001491                      이태원 관광특구
# 459506      20241        U       관광특구  3001491                      이태원 관광특구
# 459507      20241        U       관광특구  3001491                      이태원 관광특구
# 459508      20241        U       관광특구  3001491                      이태원 관광특구
# 459509      20241        U       관광특구  3001491                      이태원 관광특구
#
# ...

# %%
df1.columns
# Out:
# Index(['상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명', '엑스좌표_값', '와이좌표_값',
#        '자치구_코드', '자치구_코드_명', '행정동_코드', '행정동_코드_명', '영역_면적'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['기준_년분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명', '서비스_업종_코드',
#        '서비스_업종_코드_명', '점포_수', '유사_업종_점포_수', '개업_율', '개업_점포_수', '폐업_률',
#        '폐업_점포_수', '프랜차이즈_점포_수'],
#       dtype='object')

# %%
df_road_population = pd.read_csv("./서울시 상권분석서비스(길단위인구-상권).csv", encoding='cp949')
df_road_population
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0          20252        U       관광특구  3001496             강남 마이스 관광특구
# 1          20252        U       관광특구  3001495                 잠실 관광특구
# 2          20252        U       관광특구  3001494              종로?청계 관광특구
# 3          20252        U       관광특구  3001493            동대문패션타운 관광특구
# 4          20252        U       관광특구  3001492  명동 남대문 북창동 다동 무교동 관광특구
# ...          ...      ...        ...      ...                     ...
# 42883      20191        A       골목상권  3110005                     세검정
# 42884      20191        A       골목상권  3110004                  대신고등학교
# 42885      20191        A       골목상권  3110003                 세검정초등학교
# 42886      20191        A       골목상권  3110002                 독립문역 1번
# 42887      20191        A       골목상권  3110001                  이북5도청사
#
#        총_유동인구_수  남성_유동인구_수  여성_유동인구_수  연령대_10_유동인구_수  연령대_20_유동인구_수  ...  \
# ...

# %%
df_road_population.loc[df_road_population['상권_코드_명'] == '강남 마이스 관광특구']
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  총_유동인구_수  \
# 0          20252        U       관광특구  3001496  강남 마이스 관광특구    106928
# 1649       20251        U       관광특구  3001496  강남 마이스 관광특구    100649
# 3299       20244        U       관광특구  3001496  강남 마이스 관광특구    105501
# 4948       20243        U       관광특구  3001496  강남 마이스 관광특구    108678
# 6596       20242        U       관광특구  3001496  강남 마이스 관광특구    106718
# 8245       20241        U       관광특구  3001496  강남 마이스 관광특구    109292
# 9894       20234        U       관광특구  3001496  강남 마이스 관광특구    113583
# 11542      20233        U       관광특구  3001496  강남 마이스 관광특구    116820
# 13191      20232        U       관광특구  3001496  강남 마이스 관광특구    111108
# 14840      20231        U       관광특구  3001496  강남 마이스 관광특구    109623
# 16489      20224        U       관광특구  3001496  강남 마이스 관광특구    113561
# 18138      20223        U       관광특구  3001496  강남 마이스 관광특구    113638
# 19788      20222        U       관광특구  3001496  강남 마이스 관광특구    107600
# ...

# %%
df_max = df_road_population[df_road_population['기준_년분기_코드'] == df_road_population['기준_년분기_코드'].max()]
df_max
# Out:
#       기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0         20252        U       관광특구  3001496             강남 마이스 관광특구
# 1         20252        U       관광특구  3001495                 잠실 관광특구
# 2         20252        U       관광특구  3001494              종로?청계 관광특구
# 3         20252        U       관광특구  3001493            동대문패션타운 관광특구
# 4         20252        U       관광특구  3001492  명동 남대문 북창동 다동 무교동 관광특구
# ...         ...      ...        ...      ...                     ...
# 1644      20252        A       골목상권  3110005                     세검정
# 1645      20252        A       골목상권  3110004                  대신고등학교
# 1646      20252        A       골목상권  3110003                 세검정초등학교
# 1647      20252        A       골목상권  3110002                 독립문역 1번
# 1648      20252        A       골목상권  3110001                  이북5도청사
#
#       총_유동인구_수  남성_유동인구_수  여성_유동인구_수  연령대_10_유동인구_수  연령대_20_유동인구_수  ...  \
# ...

# %%
df_max.loc[df_max['상권_코드_명'] == '강남 마이스 관광특구']
# Out:
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  총_유동인구_수  남성_유동인구_수  \
# 0      20252        U       관광특구  3001496  강남 마이스 관광특구    106928      52435
#
#    여성_유동인구_수  연령대_10_유동인구_수  연령대_20_유동인구_수  ...  시간대_14_17_유동인구_수  \
# 0      54493           7088          21778  ...             27043
#
#    시간대_17_21_유동인구_수  시간대_21_24_유동인구_수  월요일_유동인구_수  화요일_유동인구_수  수요일_유동인구_수  \
# 0             21393              5266       15044       15308       17475
#
#    목요일_유동인구_수  금요일_유동인구_수  토요일_유동인구_수  일요일_유동인구_수
# 0       18170       17152       13095       10684
#
# [1 rows x 27 columns]

# %%
df_store = pd.read_csv('./서울시 상권분석서비스(점포-상권).csv', encoding='cp949')

# %%
cond_latest_store = df_store['기준_년분기_코드'] == df_store['기준_년분기_코드'].max()
cond_area_store   = df_store['상권_코드_명'] == '강남 마이스 관광특구'
selected_store = df_store[cond_latest_store & cond_area_store]
total_store = selected_store['점포_수'].sum()

# %%
selected_store
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 75718      20252        U       관광특구  3001496  강남 마이스 관광특구  CS300043
# 75719      20252        U       관광특구  3001496  강남 마이스 관광특구  CS300041
# 75720      20252        U       관광특구  3001496  강남 마이스 관광특구  CS300038
# 75721      20252        U       관광특구  3001496  강남 마이스 관광특구  CS300037
# 75722      20252        U       관광특구  3001496  강남 마이스 관광특구  CS300036
# ...          ...      ...        ...      ...          ...       ...
# 75782      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100005
# 75783      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100004
# 75784      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100003
# 75785      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100002
# 75786      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100001
#
#       서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# ...

# %%
total_store
# Out:
# np.int64(1033)

# %%
df_sales = pd.read_csv('./서울시 상권분석서비스(추정매출-상권).csv', encoding='cp949')

# %%
cond_latest_sales = df_sales['기준_년분기_코드'] == df_sales['기준_년분기_코드'].max()
cond_area_sales   = df_sales['상권_코드_명'] == '강남 마이스 관광특구'
selected_sales = df_sales[cond_latest_sales & cond_area_sales]
selected_sales
# Out:
#         기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 130028      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100001
# 130029      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100002
# 130030      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100003
# 130031      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100004
# 130032      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100005
# 130033      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100006
# 130034      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100008
# 130035      20252        U       관광특구  3001496  강남 마이스 관광특구  CS100010
# 130036      20252        U       관광특구  3001496  강남 마이스 관광특구  CS200006
# 130037      20252        U       관광특구  3001496  강남 마이스 관광특구  CS200028
# 130038      20252        U       관광특구  3001496  강남 마이스 관광특구  CS200030
# 130039      20252        U       관광특구  3001496  강남 마이스 관광특구  CS300001
# ...

# %%
total_sales= selected_sales['당월_매출_금액'].sum()

# %%
df_resident_population = pd.read_csv('./서울시 상권분석서비스(상주인구-상권).csv', encoding='cp949')
df_worker_population = pd.read_csv('./서울시 상권분석서비스(직장인구-상권).csv', encoding='cp949')

# %%
df_resident_population = pd.read_csv('./서울시 상권분석서비스(상주인구-상권).csv', encoding='cp949')
df_worker_population = pd.read_csv('./서울시 상권분석서비스(직장인구-상권).csv', encoding='cp949')

# %%
df_resident_population.head()
# Out:
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  총_상주인구_수  남성_상주인구_수  \
# 0      20241        R       전통시장  3130193         신수시장        59         27
# 1      20251        R       전통시장  3130289         봉일시장         1          1
# 2      20194        R       전통시장  3130304         신사상가         2          1
# 3      20241        R       전통시장  3130250  삼구시장(로타리상가)         4          2
# 4      20241        A       골목상권  3110527       홍제역 2번      4722       2191
#
#    여성_상주인구_수  연령대_10_상주인구_수  연령대_20_상주인구_수  ...  남성연령대_60_이상_상주인구_수  \
# 0         32              5              6  ...                   7
# 1          0              0              0  ...                   1
# 2          1              0              0  ...                   0
# 3          2              0              0  ...                   2
# 4       2531            690            585  ...                 480
#
#    여성연령대_10_상주인구_수  여성연령대_20_상주인구_수  여성연령대_30_상주인구_수  여성연령대_40_상주인구_수  \
# ...

# %%
df_resident_population[df_resident_population['상권_코드_명'] == '강남 마이스 관광특구']
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  총_상주인구_수  \
# 847        20252        U       관광특구  3001496  강남 마이스 관광특구        34
# 1991       20241        U       관광특구  3001496  강남 마이스 관광특구        34
# 3783       20242        U       관광특구  3001496  강남 마이스 관광특구        34
# 5227       20243        U       관광특구  3001496  강남 마이스 관광특구        34
# 6912       20251        U       관광특구  3001496  강남 마이스 관광특구        34
# 8541       20244        U       관광특구  3001496  강남 마이스 관광특구        34
# 11446      20194        U       관광특구  3001496  강남 마이스 관광특구        24
# 11892      20201        U       관광특구  3001496  강남 마이스 관광특구        24
# 13590      20223        U       관광특구  3001496  강남 마이스 관광특구        29
# 17180      20202        U       관광특구  3001496  강남 마이스 관광특구        24
# 18386      20224        U       관광특구  3001496  강남 마이스 관광특구        19
# 20373      20203        U       관광특구  3001496  강남 마이스 관광특구        24
# 21568      20204        U       관광특구  3001496  강남 마이스 관광특구        29
# ...

# %%
df_worker_population
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드               상권_코드_명  \
# 0          20252        R       전통시장  3130019               동대문상가D동
# 1          20252        A       골목상권  3110005                   세검정
# 2          20252        A       골목상권  3110023                 서울대병원
# 3          20252        D       발달상권  3120004                  종로구청
# 4          20252        R       전통시장  3130018  동대문문구완구거리(동대문문구완구시장)
# ...          ...      ...        ...      ...                   ...
# 42553      20243        D       발달상권  3120238                   방이역
# 42554      20243        D       발달상권  3120233                 몽촌토성역
# 42555      20243        A       골목상권  3111035           오금공원(오주중학교)
# 42556      20243        A       골목상권  3111046           마천역(마천초등학교)
# 42557      20243        A       골목상권  3110960                  은광여고
#
#        총_직장_인구_수  남성_직장_인구_수  여성_직장_인구_수  연령대_10_직장_인구_수  연령대_20_직장_인구_수  ...  \
# ...

# %%
df_sales = pd.read_csv('./서울시 상권분석서비스(추정매출-상권).csv', encoding='cp949')

# %%
df_sales['당월_매출_금액'].idxmin()
# Out:
# 12755

# %%
cond_latest_sales = df_sales['기준_년분기_코드'] == 20252
cond_area_sales   = df_sales['상권_코드_명'] == '개포지하차도 북측'
selected_sales = df_sales[cond_latest_sales & cond_area_sales]
total_sales= selected_sales['당월_매출_금액'].sum()
print(total_sales)
# Out:
# 0

# %%
selected_sales = df_sales[cond_latest_sales & cond_area_sales]
selected_sales
# Out:
# Empty DataFrame
# Columns: [기준_년분기_코드, 상권_구분_코드, 상권_구분_코드_명, 상권_코드, 상권_코드_명, 서비스_업종_코드, 서비스_업종_코드_명, 당월_매출_금액, 당월_매출_건수, 주중_매출_금액, 주말_매출_금액, 월요일_매출_금액, 화요일_매출_금액, 수요일_매출_금액, 목요일_매출_금액, 금요일_매출_금액, 토요일_매출_금액, 일요일_매출_금액, 시간대_00~06_매출_금액, 시간대_06~11_매출_금액, 시간대_11~14_매출_금액, 시간대_14~17_매출_금액, 시간대_17~21_매출_금액, 시간대_21~24_매출_금액, 남성_매출_금액, 여성_매출_금액, 연령대_10_매출_금액, 연령대_20_매출_금액, 연령대_30_매출_금액, 연령대_40_매출_금액, 연령대_50_매출_금액, 연령대_60_이상_매출_금액, 주중_매출_건수, 주말_매출_건수, 월요일_매출_건수, 화요일_매출_건수, 수요일_매출_건수, 목요일_매출_건수, 금요일_매출_건수, 토요일_매출_건수, 일요일_매출_건수, 시간대_건수~06_매출_건수, 시간대_건수~11_매출_건수, 시간대_건수~14_매출_건수, 시간대_건수~17_매출_건수, 시간대_건수~21_매출_건수, 시간대_건수~24_매출_건수, 남성_매출_건수, 여성_매출_건수, 연령대_10_매출_건수, 연령대_20_매출_건수, 연령대_30_매출_건수, 연령대_40_매출_건수, 연령대_50_매출_건수, 연령대_60_이상_매출_건수]
# Index: []
#
# [0 rows x 55 columns]

# %%
df_sales['기준_년분기_코드'].max()
# Out:
# np.int64(20252)

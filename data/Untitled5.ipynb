# %%
import pandas as pd

# %%
df_change = pd.read_csv('./서울시 상권분석서비스(상권변화지표-상권)_filtered.csv', encoding='cp949')
df_change
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드          상권_코드_명 상권_변화_지표  \
# 0          20192        A       골목상권  3110008  배화여자대학교(박노수미술관)       LH
# 1          20193        A       골목상권  3110008  배화여자대학교(박노수미술관)       LL
# 2          20194        A       골목상권  3110008  배화여자대학교(박노수미술관)       LL
# 3          20201        A       골목상권  3110008  배화여자대학교(박노수미술관)       LL
# 4          20202        A       골목상권  3110008  배화여자대학교(박노수미술관)       LL
# ...          ...      ...        ...      ...              ...      ...
# 38683      20243        U       관광특구  3001493     동대문패션타운 관광특구       HH
# 38684      20241        U       관광특구  3001495          잠실 관광특구       LL
# 38685      20242        U       관광특구  3001495          잠실 관광특구       LL
# 38686      20243        U       관광특구  3001495          잠실 관광특구       LL
# 38687      20243        U       관광특구  3001496      강남 마이스 관광특구       HH
#
#       상권_변화_지표_명  운영_영업_개월_평균  폐업_영업_개월_평균  서울_운영_영업_개월_평균  서울_폐업_영업_개월_평균
# ...
